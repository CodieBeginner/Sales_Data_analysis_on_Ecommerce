# %% [markdown]
# # READ FEATHER DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_feather(r"C:\Users\swarn\Desktop\Sales Data Analysis/Sales_data.ftr")
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data = pd.read_feather(r"C:\Users\swarn\Desktop\Sales Data Analysis/Sales_data.ftr")

# %%
all_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data = all_data.dropna(how='all')

# %%
all_data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
all_data[all_data.duplicated()]
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# 1302      177795    Apple Airpods Headphones                 1         150
# 1684      178158        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 186563  Order ID                     Product  Quantity Ordered  Price Each
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
#
#             Order Date                        Purchase Address
# ...

# %%
all_data = all_data.drop_duplicates()

# %%
all_data.shape
# Out:
# (185687, 6)

# %%
all_data[all_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %% [markdown]
# # BEST MONTH FOR SALE

# %%
all_data['Order Date'][0]
# Out:
# '04/19/19 08:46'

# %%
'04/19/19 08:46'.split('/')[0]
# Out:
# '04'

# %%
all_data['Order Date'][0].split('/')[0]
# Out:
# '04'

# %%
def return_month(x):
    return x.split('/')[0]

# %%
all_data['Month'] = all_data['Order Date'].apply(return_month)

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# city                object
# dtype: object

# %%
all_data['Month'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 all_data['Month'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
all_data['Month'].unique()
# Out:
# array(['04', '05', 'Order Date', '08', '09', '12', '01', '02', '03', '07',
#        '06', '11', '10'], dtype=object)

# %%
filter1 = all_data['Month'] == 'Order Date'

# %%
all_data = all_data[~filter1]

# %%
all_data.shape
# Out:
# (185686, 8)

# %%
all_data['Month'] = all_data['Month'].astype(int)
# Out:
# C:\Users\swarn\AppData\Local\Temp\ipykernel_181416\2675840658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month'] = all_data['Month'].astype(int)

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# city                object
# dtype: object

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype(int)
all_data['Price Each'] = all_data['Price Each'].astype(float)
# Out:
# C:\Users\swarn\AppData\Local\Temp\ipykernel_181416\1372988587.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype(int)
# C:\Users\swarn\AppData\Local\Temp\ipykernel_181416\1372988587.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Price Each'] = all_data['Price Each'].astype(float)

# %%
all_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# city                 object
# dtype: object

# %%
all_data['sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
# Out:
# C:\Users\swarn\AppData\Local\Temp\ipykernel_181416\2752844932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['sales'] = all_data['Quantity Ordered'] * all_data['Price Each']

# %%
all_data.groupby(['Month'])['sales'].sum()
# Out:
# Month
# 1     1821413.16
# 2     2200078.08
# 3     2804973.35
# 4     3389217.98
# 5     3150616.23
# 6     2576280.15
# 7     2646461.32
# 8     2241083.37
# 9     2094465.69
# 10    3734777.86
# 11    3197875.05
# 12    4608295.70
# Name: sales, dtype: float64

# %%
Sales_data = all_data.groupby(['Month'])['sales'].sum()

# %%
Sales_data.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
Sales_data.plot(kind='line')
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # CITY WITH MAXIMUM ORDER

# %%
all_data.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address Month
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215    04

# %%
all_data['Purchase Address'][0]
# Out:
# '917 1st St, Dallas, TX 75001'

# %%
all_data['Purchase Address'][0].split(',')[1]
# Out:
# ' Dallas'

# %%
all_data['city'] = all_data['Purchase Address'].str.split(',').str.get(1)

# %%
pd.value_counts(all_data['city'])
# Out:
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: city, dtype: int64

# %%
pd.value_counts(all_data['city']).plot(kind='pie', autopct = '%1.0f%%')
# Out:
# <Axes: ylabel='city'>

# %% [markdown]
# # MOST PRODUCT SOLD

# %%
all_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'city', 'sales'],
#       dtype='object')

# %%
count_df = all_data.groupby(['Product']).agg({'Quantity Ordered': 'sum', 'Price Each': 'mean'})

# %%
count_df = count_df.reset_index()

# %%
count_df
# Out:
#                        Product  Quantity Ordered  Price Each
# 0                 20in Monitor              4126      109.99
# 1       27in 4K Gaming Monitor              6239      389.99
# 2             27in FHD Monitor              7541      149.99
# 3       34in Ultrawide Monitor              6192      379.99
# 4        AA Batteries (4-pack)             27615        3.84
# 5       AAA Batteries (4-pack)             30986        2.99
# 6     Apple Airpods Headphones             15637      150.00
# 7   Bose SoundSport Headphones             13430       99.99
# 8                Flatscreen TV              4813      300.00
# 9                 Google Phone              5529      600.00
# 10                    LG Dryer               646      600.00
# 11          LG Washing Machine               666      600.00
# 12    Lightning Charging Cable             23169       14.95
# 13          Macbook Pro Laptop              4725     1700.00
# ...

# %%
products= count_df['Product'].values

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()

ax1.bar(count_df['Product'], count_df['Quantity Ordered'], color='g')
ax2.plot(count_df['Product'], count_df['Price Each'])
ax1.set_xticklabels(products, rotation='vertical', fontsize=8)
ax2.set_ylabel('Order Count')
ax2.set_ylabel('Avg price of product')
# Out:
# C:\Users\swarn\AppData\Local\Temp\ipykernel_181416\3504768487.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products, rotation='vertical', fontsize=8)
# Text(0, 0.5, 'Avg price of product')

# %% [markdown]
# # TREND OF THE SALES

# %%
all_data['Product'].value_counts()[0:5].index
# Out:
# Index(['USB-C Charging Cable', 'Lightning Charging Cable',
#        'AAA Batteries (4-pack)', 'AA Batteries (4-pack)', 'Wired Headphones'],
#       dtype='object')

# %%
most_sold_products = all_data['Product'].value_counts()[0:5].index

# %%
all_data['Product'].isin(most_sold_products)
# Out:
# 0          True
# 2         False
# 3         False
# 4          True
# 5          True
#           ...
# 186845     True
# 186846    False
# 186847    False
# 186848    False
# 186849     True
# Name: Product, Length: 185686, dtype: bool

# %%
most_sold_products_df = all_data[all_data['Product'].isin(most_sold_products)]

# %%
most_sold_products_df.head(5)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   176558  USB-C Charging Cable                 2       11.95
# 4   176560      Wired Headphones                 1       11.99
# 5   176561      Wired Headphones                 1       11.99
# 6   176562  USB-C Charging Cable                 1       11.95
# 8   176564  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month  \
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001      4
# 4  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27       333 8th St, Los Angeles, CA 90001      4
# 6  04/29/19 13:03  381 Wilson St, San Francisco, CA 94016      4
# 8  04/12/19 10:58         790 Ridge St, Atlanta, GA 30301      4
#
#              city  sales
# 0          Dallas  23.90
# 4     Los Angeles  11.99
# 5     Los Angeles  11.99
# 6   San Francisco  11.95
# 8         Atlanta  11.95

# %%
pivot = most_sold_products_df.groupby(['Month', 'Product']).size().unstack()

# %%
pivot.plot(figsize=(8,6))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# # PDODUCTS MOST SOLD TOGETHER

# %%
df_duplicated = all_data[all_data['Order ID'].duplicated(keep=False)]

# %%
df_duplicated
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  \
# ...

# %%
dup_products = df_duplicated.groupby(['Order ID'])['Product'].apply(lambda x : ','.join(x)).reset_index().rename(columns={'Product' : 'grouped_products'})

# %%
dup_products_df = df_duplicated.merge(dup_products, how='left', on='Order ID')

# %%
no_dup_df = dup_products_df.drop_duplicates(subset=['Order ID'])

# %%
no_dup_df
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 0       176560              Google Phone                 1      600.00
# 2       176574              Google Phone                 1      600.00
# 4       176586    AAA Batteries (4-pack)                 2        2.99
# 6       176672  Lightning Charging Cable                 1       14.95
# 8       176681  Apple Airpods Headphones                 1      150.00
# ...        ...                       ...               ...         ...
# 14118   259277                    iPhone                 1      700.00
# 14120   259297                    iPhone                 1      700.00
# 14122   259303    34in Ultrawide Monitor                 1      379.99
# 14124   259314          Wired Headphones                 1       11.99
# 14126   259350              Google Phone                 1      600.00
#
#            Order Date                        Purchase Address  Month  \
# ...

# %%
no_dup_df['grouped_products'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='grouped_products'>

# %%
no_dup_df['grouped_products'].value_counts()[0:10].plot.pie()
# Out:
# <Axes: ylabel='grouped_products'>
